# %%
import pandas as pd

# %%
# pd.read_csv("/home/intern_fjq_2026/Projects/chinese-wwm-roberta/filtered_data/social_text_202403.csv.gz")

# %%
import pymysql

conn = pymysql.connect(
    host='10.80.139.20',
    user='chenrongjun',          
    password='40!VEz6QX',       
    database='datayes',
    charset='utf8',
)
cursor = conn.cursor()
cursor.execute('SELECT VERSION(), DATABASE(), CURRENT_USER()')
print('✅ 连接成功:', cursor.fetchone())
# Out:
# ✅ 连接成功: ('8.0.30', 'datayes', 'chenrongjun@%')

# %%
comment_info = pd.read_sql("""
    SELECT TABLE_NAME, TABLE_COMMENT
    FROM information_schema.tables 
    WHERE table_schema = DATABASE()
      AND TABLE_COMMENT != ''
    ORDER BY TABLE_NAME
    LIMIT 350, 25
""", conn)

print("=== 有注释的表 ===")
if len(comment_info) > 0:
    print(comment_info.to_string(index=False))
else:
    print("(暂无)")
# Out:
# === 有注释的表 ===
#           TABLE_NAME         TABLE_COMMENT
#         rr_gold_rank               月度金股榜单表
#   rr_gold_stock_info               金股基本信息表
#         rr_gold_view               金股核心观点表
#              rr_main              研报基础信息主表
#           rr_org_map         研报评级机构标准简称对应表
#  rr_profit_adjust_v2             个股盈利预测调整表
#       rr_profit_stat             个股盈利预测统计表
#    rr_profit_stat_3m          个股盈利预测3个月统计表
#    rr_profit_stat_6m        个股盈利预测半年度统计增量表
# rr_profit_stat_6mhis        个股盈利预测半年度统计历史表
#     rr_rating_adjust               个股评级调整表
#       rr_rating_stat               个股评级统计表
#         rr_score_map           研报评级机构评级对应表
#      rr_sentiment_v2             研报核心观点情感表
#  rr_tar_price_adjust              个股目标价调整表
# rr_tar_price_adjust2              个股目标价调整表
#   social_con_stock_g             G用户关注股明细表
#   social_con_stock_x             X用户关注股明细表
#  social_corp_score_g         G社交关联公司及情感得分表
#  social_corp_score_x         X社交关联公司及情感得分表
#        social_heat_g            G社交热度数据统计表
#      social_heat_g_1 G社交热度数据统计表(2017-2021)
#        social_heat_x            X社交热度数据统计表
#      social_heat_x_1 X社交热度数据统计表(2017-2021)
#  social_inds_tra_a_x         X源A股行业每日调仓统计表
# /tmp/ipykernel_1260/3758555440.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   comment_info = pd.read_sql("""

# %%
import pandas as pd
D = 'rr_tar_price_adjust'
# D = 'news_keywords'
# 1. 先看表结构（字段名和数据类型）
schema = pd.read_sql(f"""
    SELECT COLUMN_NAME, DATA_TYPE, IS_NULLABLE, COLUMN_DEFAULT, COLUMN_COMMENT
    FROM information_schema.columns 
    WHERE table_name = '{D}'
    ORDER BY ORDINAL_POSITION
""", conn)
print("=== 表结构 ===")
print(schema.to_string(index=False))
# Out:
# === 表结构 ===
#     COLUMN_NAME DATA_TYPE IS_NULLABLE COLUMN_DEFAULT COLUMN_COMMENT
#              ID    bigint          NO           None           信息编码
#       REPORT_ID    bigint         YES           None           报告ID
#        SEC_CODE   varchar         YES           None           证券代码
#        SEC_NAME   varchar         YES           None           证券名称
#           TITLE   varchar         YES           None             标题
#     REPORT_TYPE   varchar         YES           None           研报类型
#          ORG_ID       int         YES           None           机构ID
#        ORG_NAME   varchar         YES           None           机构简称
#          AUTHOR   varchar         YES           None             作者
# THIS_WRITE_DATE      date         YES           None         本次预测日期
# LAST_WRITE_DATE      date         YES           None         上次预测日期
#  THIS_TAR_PRICE    double         YES           None        本次预测目标价
#  LAST_TAR_PRICE    double         YES           None        上次预测目标价
#   CURRENT_PRICE    double         YES           None           当前价格
#  TAR_PRICE_MARK       int         YES           None        目标价调整标记
#     UPDATE_TIME  datetime         YES           None           更新时间
# /tmp/ipykernel_1260/2110152828.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   schema = pd.read_sql(f"""

# %%
# 2. 看前几行数据 + 总行数
count = pd.read_sql(f'SELECT COUNT(*) AS cnt FROM {D}', conn).iloc[0]['cnt']
print(f"\n=== 共 {count} 行 ===\n")
# Out:
# === 共 158098 行 ===
# /tmp/ipykernel_1260/965494187.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   count = pd.read_sql(f'SELECT COUNT(*) AS cnt FROM {D}', conn).iloc[0]['cnt']

# %%
pd.read_sql(f'SELECT * FROM {D} LIMIT 20', conn)
# Out:
# /tmp/ipykernel_1260/2643961264.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(f'SELECT * FROM {D} LIMIT 20', conn)
#     ID  REPORT_ID SEC_CODE SEC_NAME                                  TITLE  \
# 0    1    3798354   002353     杰瑞股份                    第三方检测行业：具备孕育大型企业的基因
# 1    2    3798354   002690     美亚光电                    第三方检测行业：具备孕育大型企业的基因
# 2    3    3798354   300012     华测检测                    第三方检测行业：具备孕育大型企业的基因
# 3    4    3798354   300450     先导智能                    第三方检测行业：具备孕育大型企业的基因
# 4    5    3798354   300747     锐科激光                    第三方检测行业：具备孕育大型企业的基因
# 5    6    3798354   600031     三一重工                    第三方检测行业：具备孕育大型企业的基因
# 6    7    3798354   601100     恒立液压                    第三方检测行业：具备孕育大型企业的基因
# 7    8    3798318   600066     宇通客车            宇通客车（600066）：市占率稳步提升，静待行业出清
# 8    9    3798710   600195     中牧股份              中牧股份（600195）：再添助力，公司开启新篇章
# 9   10    3797943   600376     首开股份  首开股份（600376）2019上半年业绩预增公告点评：业绩稳增，销售靓丽
# 10  11    3798034   601877     正泰电器     正泰电器（601877）：供应商参与大额持股计划，实现产业链合作共赢
# 11  12    3764560   000858      五粮液                  五粮液（000858）：决心改革，曙光显现
# 12  13    3764528   002059     云南旅游    云南旅游（002059）：注入稀缺游乐设备龙头，打造全域旅游综合服务商
# 13  14    3764913   002241     歌尔股份  歌尔股份（002241）：TWS耳机、智能手表高成长，关注VRAR未来潜力
# 14  15    3765069   002353     杰瑞股份          杰瑞股份（002353）：电驱专题研究：无限电驱，无限未来
# 15  16    3764507   002425     凯撒文化  凯撒文化（002425）：19Q2预告业绩持续高增，静待头部游戏版号及上线
# 16  17    3767031   002475     立讯精密      立讯精密（002475）：中美贸易直接影响有限，配件业务持续超预期
# 17  18    3764580   600176     中国巨石            中国巨石（600176）：新起点新征程，国际化更进一步
# 18  19    3764677   600176     中国巨石          中国巨石（600176）：美国产线点火，国际化迈出坚实一步
# 19  20    3764690   603127     昭衍新药        昭衍新药（603127）：收购Biomere，拓展国外安评市场
#
#    REPORT_TYPE  ORG_ID ORG_NAME   AUTHOR THIS_WRITE_DATE LAST_WRITE_DATE  \
# 0          R03   26455     中金公司  张梓丁,孔令鑫      2019-07-04      2019-07-02
# 1          R03   26455     中金公司  张梓丁,孔令鑫      2019-07-04      2019-07-02
# 2          R03   26455     中金公司  张梓丁,孔令鑫      2019-07-04      2019-07-02
# 3          R03   26455     中金公司  张梓丁,孔令鑫      2019-07-04      2019-07-02
# 4          R03   26455     中金公司  张梓丁,孔令鑫      2019-07-04      2019-07-02
# 5          R03   26455     中金公司  张梓丁,孔令鑫      2019-07-04      2019-07-02
# 6          R03   26455     中金公司  张梓丁,孔令鑫      2019-07-04      2019-07-02
# 7          R04   26455     中金公司    奉玮,常菁      2019-07-04      2019-04-26
# 8          R04     923     西南证券       徐卿      2019-07-04      2019-04-30
# 9          R04   27002     华创证券       袁豪      2019-07-04      2019-06-11
# 10         R04   26959     东吴证券      曾朵红      2019-07-04      2019-04-29
# 11         R04    1786   国泰君安证券    訾猛,马铮      2019-05-19      2019-04-29
# 12         R04    1786   国泰君安证券  刘越男,芦冠宇      2019-05-19      2019-04-28
# 13         R04   26455     中金公司  胡誉镜,黄乐平      2019-05-19      2019-04-26
# 14         R04     339     广发证券  刘芷君,罗立波      2019-05-19      2019-04-26
# 15         R04   15750     天风证券   文浩,冯翠婷      2019-05-19      2019-03-18
# 16         R04   26455     中金公司  胡誉镜,黄乐平      2019-05-19      2019-04-29
# 17         R04    1786   国泰君安证券  鲍雁辛,赵晨阳      2019-05-19      2019-04-25
# 18         R04   27776    太平洋证券    闫广,郁晾      2019-05-19      2019-04-25
# 19         R04   26465     东方证券      伍云飞      2019-05-19      2019-05-08
#
#     THIS_TAR_PRICE  LAST_TAR_PRICE  CURRENT_PRICE  TAR_PRICE_MARK  \
# 0              NaN           33.80          23.80               3
# 1              NaN           35.82          32.12               3
# 2              NaN           11.28          10.67               3
# 3              NaN           41.00          33.72               3
# 4              NaN          167.13         147.03               3
# 5              NaN           16.20          12.92               3
# 6              NaN           40.52          31.24               3
# 7            18.00           18.00          13.69               0
# 8            21.75           17.40          15.32               1
# 9            12.67           12.67           9.42               0
# 10           33.48           33.48          23.41               0
# 11          130.00          130.00            NaN               0
# 12            9.06            9.06            NaN               0
# 13           13.00           13.00            NaN               0
# 14           28.45           28.45            NaN               0
# 15           14.20           14.20            NaN               0
# 16           32.00           32.00            NaN               0
# 17           18.40           18.40            NaN               0
# 18           14.86           14.86            NaN               0
# 19           54.32           54.32            NaN               0
#
#            UPDATE_TIME
# 0  2019-07-11 10:09:29
# 1  2019-07-11 10:09:29
# 2  2019-07-11 10:09:29
# 3  2019-07-11 10:09:29
# 4  2019-07-11 10:09:29
# 5  2019-07-11 10:09:29
# 6  2019-07-11 10:09:29
# 7  2019-07-04 19:36:07
# 8  2019-07-04 19:36:07
# 9  2019-07-04 19:36:07
# 10 2019-07-04 19:36:07
# 11 2019-07-11 10:34:56
# 12 2019-07-11 10:34:56
# 13 2019-07-11 10:34:56
# 14 2019-07-11 10:34:56
# 15 2019-07-11 10:34:56
# 16 2019-07-11 10:34:56
# 17 2019-07-11 10:34:56
# 18 2019-07-11 10:34:56
# 19 2019-07-11 10:34:56

# %%
date_col = "UPDATE_TIME"
time_range = pd.read_sql(f"""
    SELECT MIN({date_col}) AS min_date, MAX({date_col}) AS max_date
    FROM {D}
""", conn)
print(f"统计日期范围：{time_range['min_date'].values[0]} → {time_range['max_date'].values[0]}")
print(f"共跨越 {len(pd.date_range(time_range['min_date'].values[0], time_range['max_date'].values[0]))} 个交易日")
# Out:
# 统计日期范围：2018-07-31T19:37:50.000000000 → 2026-09-04T18:36:08.000000000
# 共跨越 2957 个交易日
# /tmp/ipykernel_1260/2943031222.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   time_range = pd.read_sql(f"""

# %%
symbol_col = "TICKER_SYMBOL"
pd.read_sql(f"""
    SELECT 
        AVG(cnt) AS avg_symbols_per_day
    FROM (
        SELECT COUNT(DISTINCT {symbol_col}) AS cnt
        FROM {D}
        WHERE {symbol_col} NOT LIKE '8%'
          AND {symbol_col} NOT LIKE '9%'
        GROUP BY {date_col}
    ) subq
""", conn)
# Out:
# /tmp/ipykernel_11251/1156218629.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(f"""
#    avg_symbols_per_day
# 0            4670.3838
