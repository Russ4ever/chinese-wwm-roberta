# %%
import pandas as pd

# %%
pd.read_csv("/home/intern_fjq_2026/Projects/chinese-wwm-roberta/artifacts/label_engineering/rank_ic_summary.csv")
# Out:
#      factor  horizon   ic_mean    ic_std      icir    t_stat  ic_gt0_pct  \
# 0   eps_neu  rtn_10d -0.003506  0.113286 -0.030951 -0.480485    0.510373
# 1   eps_neu   rtn_1d -0.006345  0.106840 -0.059383 -0.921879    0.497925
# 2   eps_neu  rtn_20d -0.009935  0.113569 -0.087483 -1.358094    0.493776
# 3   eps_neu   rtn_5d -0.005735  0.106643 -0.053777 -0.834849    0.468880
# 4    np_neu  rtn_10d  0.035487  0.117067  0.303133  4.705896    0.614108
# 5    np_neu   rtn_1d  0.032226  0.118821  0.271216  4.210401    0.576763
# 6    np_neu  rtn_20d  0.035691  0.114450  0.311850  4.841213    0.634855
# 7    np_neu   rtn_5d  0.036315  0.118378  0.306772  4.762378    0.618257
# 8   or__neu  rtn_10d  0.023122  0.119874  0.192884  2.975665    0.605042
# 9   or__neu   rtn_1d  0.020929  0.123047  0.170086  2.623961    0.584034
# 10  or__neu  rtn_20d  0.023485  0.107378  0.218709  3.374077    0.554622
# 11  or__neu   rtn_5d  0.022606  0.122236  0.184936  2.853057    0.584034
# ...
